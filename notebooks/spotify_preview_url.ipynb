# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import pandas as pd
import os

# %%
scope = 'playlist-modify-public'
username = 'buggy0811'    
token = SpotifyOAuth(scope = os.environ['SPOTIFY_SCOPE'],
                    username = os.environ['SPOTIFY_USERNAME'],
                    client_id = os.environ['SPOTIFY_CLIENT_ID'],
                    client_secret = os.environ['SPOTIFY_CLIENT_SECRET'],
                    redirect_uri = 'http://127.0.0.1:8080/')
sp = spotipy.Spotify(auth_manager = token)

# %%
search = 'tim maia o descobridor'

# %%
res = sp.search(q = search)

# %%
res.keys()
# Out:
# dict_keys(['tracks'])

# %%
res['tracks']['items'][0]
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0jOs0wnXCu1bGGP7kh5uIu'},
#     'href': 'https://api.spotify.com/v1/artists/0jOs0wnXCu1bGGP7kh5uIu',
#     'id': '0jOs0wnXCu1bGGP7kh5uIu',
#     'name': 'Tim Maia',
#     'type': 'artist',
#     'uri': 'spotify:artist:0jOs0wnXCu1bGGP7kh5uIu'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'ET',
#    'FI',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/7Ff0Q5oeEoVKHtxJJoXyId'},
#   'href': 'https://api.spotify.com/v1/albums/7Ff0Q5oeEoVKHtxJJoXyId',
#   'id': '7Ff0Q5oeEoVKHtxJJoXyId',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273bf96aed03a1e378dad91217b',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02bf96aed03a1e378dad91217b',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851bf96aed03a1e378dad91217b',
#     'width': 64}],
#   'name': 'O Descobridor Dos Sete Mares',
#   'release_date': '1983-01-03',
#   'release_date_precision': 'day',
#   'total_tracks': 10,
#   'type': 'album',
#   'uri': 'spotify:album:7Ff0Q5oeEoVKHtxJJoXyId'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0jOs0wnXCu1bGGP7kh5uIu'},
#    'href': 'https://api.spotify.com/v1/artists/0jOs0wnXCu1bGGP7kh5uIu',
#    'id': '0jOs0wnXCu1bGGP7kh5uIu',
#    'name': 'Tim Maia',
#    'type': 'artist',
#    'uri': 'spotify:artist:0jOs0wnXCu1bGGP7kh5uIu'}],
#  'available_markets': ['AR',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
#   'UG',
#   'AG',
#   'AM',
#   'BS',
#   'BB',
#   'BZ',
#   'BT',
#   'BW',
#   'BF',
#   'CV',
#   'CW',
#   'DM',
#   'GM',
#   'GE',
#   'GD',
#   'GW',
#   'GY',
#   'HT',
#   'JM',
#   'KI',
#   'LS',
#   'LR',
#   'MW',
#   'MV',
#   'ML',
#   'MH',
#   'FM',
#   'NA',
#   'NR',
#   'NE',
#   'PW',
#   'PG',
#   'WS',
#   'SM',
#   'ST',
#   'SN',
#   'SC',
#   'SL',
#   'SB',
#   'KN',
#   'LC',
#   'VC',
#   'SR',
#   'TL',
#   'TO',
#   'TT',
#   'TV',
#   'VU',
#   'AZ',
#   'BN',
#   'BI',
#   'KH',
#   'CM',
#   'TD',
#   'KM',
#   'GQ',
#   'SZ',
#   'GA',
#   'GN',
#   'KG',
#   'LA',
#   'MO',
#   'MR',
#   'MN',
#   'NP',
#   'RW',
#   'TG',
#   'UZ',
#   'ZW',
#   'BJ',
#   'MG',
#   'MU',
#   'MZ',
#   'AO',
#   'CI',
#   'DJ',
#   'ZM',
#   'CD',
#   'CG',
#   'IQ',
#   'LY',
#   'TJ',
#   'VE',
#   'ET',
#   'XK'],
#  'disc_number': 1,
#  'duration_ms': 265297,
#  'explicit': False,
#  'external_ids': {'isrc': 'BRMCA8300131'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/6wpDQGn3Gl0j9Wt6D6mYvQ'},
#  'href': 'https://api.spotify.com/v1/tracks/6wpDQGn3Gl0j9Wt6D6mYvQ',
#  'id': '6wpDQGn3Gl0j9Wt6D6mYvQ',
#  'is_local': False,
#  'name': 'O Descobridor Dos Sete Mares',
#  'popularity': 64,
#  'preview_url': 'https://p.scdn.co/mp3-preview/1bf99c2808f44cf89dd9f42e6e3a7804362e53ed?cid=3d24a9c30a8348af9da7088a04163f6b',
#  'track_number': 1,
#  'type': 'track',
#  'uri': 'spotify:track:6wpDQGn3Gl0j9Wt6D6mYvQ'}
