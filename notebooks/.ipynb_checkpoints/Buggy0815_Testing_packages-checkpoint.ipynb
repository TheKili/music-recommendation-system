# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import os
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics.pairwise import cosine_similarity
import sys
import os
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Get the parent directory path
parent_dir = os.path.dirname(os.path.abspath(''))
# Add the parent directory to sys.path
sys.path.append(parent_dir)

# %%
from recommender.memory_based import drop_duplicated, get_recommendations
from recommender.utils_spotify import get_track_info

# %%
data_path = os.path.join(os.path.dirname(os.getcwd()), 'raw_data/dataset.csv')
df = pd.read_csv(data_path, index_col = 0)

# %%
df = drop_duplicated(df)

# %%
song = df.loc[df['track_name'] == 'Come to My Aid - 2008 Remaster']

# %%
song
# Out:
#                      track_id     artists   album_name  \
# 10351  5xe8JKOPu53Q2Fa2FRuCfZ  Simply Red  Planet 80's
#
#                            track_name  popularity  duration_ms  explicit  \
# 10351  Come to My Aid - 2008 Remaster           1       245106     False
#
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 10351         0.771   0.898   11    -6.432     0       0.0404         0.299
#
#        instrumentalness  liveness  valence    tempo  time_signature  \
# 10351            0.0899    0.0889    0.961  116.204               4
#
#                   track_genre
# 10351  [british, r-n-b, soul]

# %%
artist = 'Steve Monite'
track = 'Welcome my love'

# %%
song = get_track_info(track, artist)

# %%
song
# Out:
#                  track_id       artists album_name       track_name  \
# 0  4uMrEMndAM7oNEk4sR3rhU  Steve Monite   Only You  Welcome My Love
#
#    popularity  duration_ms  explicit  danceability  energy  key  loudness  \
# 0          40       373670     False         0.803   0.556    7   -10.498
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     0       0.0388        0.0875             0.714    0.0406    0.598
#
#      tempo  time_signature  track_genre
# 0  111.056               4  [afro-funk]

# %%
get_recommendations(song, df, n_recommendations=5, metric = 'cosine')
# Out:
#                      track_id  similarity                        track_name  \
# 22513  7xcahxhSAdTv28H4DjrisY    0.995762                            Fallin
# 22396  5RfWujDfoDdKIF70rsqo6N    0.995559                  End of All Hopes
# 38776  7jGThBg8YnpRuheRf3ueMl    0.995417  I Wanna Change - Housenick Remix
# 38837  50uih9H4g4rBYoRrEcPUPj    0.992836                         Snow Rain
# 38913  6lppAaNhgh9dqfhQDyKTvd    0.992229                     Drifting away
# 86275  0ikhyMXGBKSx8Yb18h7prS    0.991360               Imprint of Pleasure
#
#                           artist
# 22513           Oscar Mbo;C-Blak
# 22396                Furkan Sert
# 38776  Nando Fortunato;Housenick
# 38837                 Alex Spite
# 38913               Topsy Crettz
# 86275              Tube & Berger

# %%
get_recommendations(song, df, n_recommendations=5, metric = 'rbf')
# Out:
#                      track_id  similarity                        track_name  \
# 22513  7xcahxhSAdTv28H4DjrisY    0.998093                            Fallin
# 22396  5RfWujDfoDdKIF70rsqo6N    0.997167                  End of All Hopes
# 38913  6lppAaNhgh9dqfhQDyKTvd    0.996449                     Drifting away
# 38776  7jGThBg8YnpRuheRf3ueMl    0.996102  I Wanna Change - Housenick Remix
# 82413  7tSFbpe1KLESU6k3v2eBPA    0.995956                    Ramen and Herb
# 27137  3M7iGumQg71Px5ckGJgJYR    0.995716                        The Dragon
#
#                           artist
# 22513           Oscar Mbo;C-Blak
# 22396                Furkan Sert
# 38913               Topsy Crettz
# 38776  Nando Fortunato;Housenick
# 82413              Ferris Ferris
# 27137                Groundation

# %%
get_recommendations(song, df, n_recommendations=5, metric= 'sigmoid')
# Out:
#                      track_id  similarity                  track_name  \
# 7868   0LoQuiekvzqx7n8flgEKzF    0.858471                   Get It On
# 16410  1TDaJdffDuZo7jVOpWkgg1    0.858322  I Wanna Rock (Jersey Club)
# 22049  6KsWTg6la3h3LeLcQZ2uoD    0.856987        Headnoise (Get Hype)
# 1724   3pbjRPcTq1UXgojOXxtkm4    0.856677            Don't Contradict
# 26072  4R1ucIN3cgWBcHxbeSmgzB    0.856299                 Gammy Elbow
# 61167  0aUtDDfbI5EKUJDaUKRM9B    0.855628                 Rusty Nails
#
#                              artist
# 7868                         T. Rex
# 16410                 DJ Smallz 732
# 22049  Martin Ikin;Dope Earth Alien
# 1724                Ikebe Shakedown
# 26072         DJ Zinc;Chris Lorenzo
# 61167                       Moderat
