# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import os
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics.pairwise import cosine_similarity
import sys
import os
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Get the parent directory path
parent_dir = os.path.dirname(os.path.abspath(''))
# Add the parent directory to sys.path
sys.path.append(parent_dir)

# %%
from recommender.memory_based import Memory

# %%
data_path = os.path.join(os.path.dirname(os.getcwd()), 'raw_data/dataset.csv')
df = pd.read_csv(data_path, index_col = 0)

# %%
df.columns
# Out:
# Index(['track_id', 'artists', 'album_name', 'track_name', 'popularity',
#        'duration_ms', 'explicit', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature', 'track_genre'],
#       dtype='object')

# %%
df.loc[df.duplicated(subset = ['artists', 'track_name'], keep = False)].sort_values(by = ['artists', 'track_name'])
# Out:
#                       track_id     artists album_name       track_name  \
# 58516   5h7RBt7uQCF788tr9Zy92j  (Hed) P.E.      Broke       Crazy Legs
# 58857   5igKQzi92vVl9Pjj86d42O  (Hed) P.E.      Broke       Crazy Legs
# 58306   7kv31DonKok7StOsCdvoBT  (Hed) P.E.      Broke   Waiting to Die
# 58874   0aiP8ezzmk3W1GRvnQYDCA  (Hed) P.E.      Broke   Waiting to Die
# 63488   3KYALFgiqZLKScioJGqz8a     10-FEET  VANDALIZE            SHOES
# ...                        ...         ...        ...              ...
# 102361  6la3Kme7O7D01fJPxgpAS5         詹雯婷         訣愛  訣愛 (劇集《蒼蘭訣》片頭曲)
# 12466   1o7LoJTQd4Js16rHjTKAc9         陳秋霞      第二道彩虹              六月天
# 70920   1o7LoJTQd4Js16rHjTKAc9         陳秋霞      第二道彩虹              六月天
# 62250   1dGF5ymTyBB2ZmOypkeU1F        須田景凪      porte             veil
# 62603   1QkEUbGSlp70DYNFcxcxYI        須田景凪     Billow             veil
#
#         popularity  duration_ms  explicit  danceability  energy  key  \
# ...

# %%
mem = Memory()

# %%
df = mem.drop_duplicated(df)

# %%
song = df.loc[df['track_name'] == 'Come to My Aid - 2008 Remaster']

# %%
song
# Out:
#                      track_id     artists   album_name  \
# 10351  5xe8JKOPu53Q2Fa2FRuCfZ  Simply Red  Planet 80's
#
#                            track_name  popularity  duration_ms  explicit  \
# 10351  Come to My Aid - 2008 Remaster           1       245106     False
#
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 10351         0.771   0.898   11    -6.432     0       0.0404         0.299
#
#        instrumentalness  liveness  valence    tempo  time_signature  \
# 10351            0.0899    0.0889    0.961  116.204               4
#
#                   track_genre
# 10351  [british, r-n-b, soul]

# %%
mem.get_recommendations(song, df, n_recommendations=5, metric = 'rbf')
# Out:
#                      track_id  similarity                      track_name  \
# 10351  5xe8JKOPu53Q2Fa2FRuCfZ    1.000000  Come to My Aid - 2008 Remaster
# 56680  7uxI3noYpxH4z6mghwoerL    0.996292                 We Got the Beat
# 28481  356ry72djzWnoIjOCrLS7h    0.995919                 Sexy Movimiento
# 61753  2kbTb1Unb8QdXAoajQLHOp    0.995897                         Alcohol
# 1915   7KDiI2Q1pJnZoTpGl7r50f    0.995854              Jorge de Capadócia
# 13101  2Fb4UYzXMcKWjeEjbElRIX    0.995801          Fantasy (Demo Version)
#
#                artist
# 10351      Simply Red
# 56680   Mini Pop Kids
# 28481  Wisin & Yandel
# 61753   Jorge Ben Jor
# 1915       cacique'97
# 13101        Ten City

# %%
mem.get_recommendations(song, df, n_recommendations=20, metric= 'sigmoid')
# Out:
#                      track_id  similarity  \
# 56312  0xu08jsGYBDmrbvq1jW1g2    0.867575
# 32309  1pOztoC78d5UyrI5jGckM9    0.867461
# 32459  5vSdOwza7jCCPPPgHtowFj    0.867258
# 32050  356Tjo0OXHtdKnEpHzcMwZ    0.867077
# 75906  6QMVzgc9sQ7cfaUo36IAKa    0.866894
# 1696   5KvJ9xhL93jx9Q8IjDUbdw    0.866735
# 75927  622Xf9AdhKZpQAUO00sNPH    0.866611
# 1724   3pbjRPcTq1UXgojOXxtkm4    0.866547
# 65621  2EnNzwYRvxU9vnTWq0dXWu    0.866538
# 79743  2okcO5ZSjMwCl3kBOZujX9    0.866219
# 64697  0BokBQTPRsjfIt8TreLzu9    0.866214
# 57757  2L95U6syP0bV3fkYYOzmiW    0.866104
# 32398  3L8Ht57x8mgTd2zZ7awnfB    0.865990
# 32433  13Gi7jT0nPM5Tm9XPJZylz    0.865867
# 32436  5qkWX9sQjSQqcMnVjBG24M    0.865853
# 27932  65ES1qwOB577ZnTkizMXJJ    0.865847
# 70455  56IhGBCFIRw9reDg2NTZSz    0.865832
# 16410  1TDaJdffDuZo7jVOpWkgg1    0.865745
# 31657  4lGTgT3KQ6poty3glR5iS7    0.865725
# 32435  0SXCRGVFT4lLgGrrxIXnpH    0.865682
# 31873  3akdskKtV6k7xeVUYvnWYp    0.865658
#
# ...
